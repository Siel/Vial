# %%
import julia
import numpy as np
julia.install()

# %%
from julia import npod
# %load_ext julia.magic
# Out:
# Initializing Julia interpreter. This may take some time...

# %%
pkdata_file = "data/data_1comp_neely.csv"
a=[0.001, 50]
b=[2, 250]
c0 = 0
c1 = 0.1
c2 = 0
(a,b,c,d,e)=npod.run("data/data_1comp_neely.csv", a, b, c0, c1, c2, 51)
# Out:
#  i=        1328
#  y(i)=   1.0000000000000000E-004
#  i=        1329
#  y(i)=   1.0000000000000000E-004
#  i=        1330
#  y(i)=   1.0000000000000000E-004
#  i=        1331
#  y(i)=   1.0000000000000000E-004
#  i=        1332
#  y(i)=   1.0000000000000000E-004
#  i=        1333
#  y(i)=   1.0000000000000000E-004
#  i=        1334
#  y(i)=   1.0000000000000000E-004
#  i=        1335
#  y(i)=   1.0000000000000000E-004
#  i=        1336
#  y(i)=   1.0000000000000000E-004
#  i=        1337
#  y(i)=   1.0000000000000000E-004
#  i=        1338
#  y(i)=   1.0000000000000000E-004
#  i=        1339
#  y(i)=   1.0000000000000000E-004
#  i=        1340
#  y(i)=   1.0000000000000000E-004
#  i=        1341
#  y(i)=   1.0000000000000000E-004
#  i=        1342
#  y(i)=   1.0000000000000000E-004
#  i=        1343
#  y(i)=   1.0000000000000000E-004
#  i=        1344
#  y(i)=   1.0000000000000000E-004
#  i=        1345
#  y(i)=   1.0000000000000000E-004
#  i=        1346
# ...

# %%
j=%julia $d[]
j
# Out:
# -1935.4481355288929

# %%
len(c)
# Out:
# 45

# %%
np.array([[2, 3],
       [4, 5]])
# Out:
# array([[2, 3],
#        [4, 5]])

# %%
param_ranges
# Out:
# [[0.001, 50], [2, 250]]

# %%
type(param_ranges)
# Out:
# list

# %%
param_ranges[0]
# Out:
# [0.001, 50]
