# %%
from npodEnv import NpodEnv
env = NpodEnv()
env.ver()
# Out:
# 0.8

# %%
observation = env.run(0)
# Out:
# [1] "dopt"
# [1] "PSI"
# [1] "Multi prob"
# [1] "Sim time:"
#    user  system elapsed
#   2.796   0.064   2.886
# [1] "prob time:"
#    user  system elapsed
#  17.128   0.036  17.342
# $fobj
# [1] 118.7015
#
# $lambda
#     [1] 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14
#     [6] 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14
#    [11] 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14
#    [16] 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14 2.113902e-14
#    [21] 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14
#    [26] 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14
#    [31] 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14
#    [36] 6.175550e-14 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14
#    [41] 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14 2.099876e-14
#    [46] 2.099876e-14 2.099876e-14 2.800160e-14 2.099876e-14 2.099876e-14
# ...

# %%
observation.keys()
observation
# Out:
# {'count': 2.0,
#  'theta': [0.05770947265625,
#   120.1171875,
#   0.298787744140625,
#   130.17578125,
#   0.082110107421875,
#   101.85546875,
#   0.0874782470703125,
#   85.888671875,
#   0.3353886962890625,
#   89.599609375,
#   0.13213140869140624,
#   94.3603515625,
#   0.09016231689453125,
#   92.1142578125,
#   0.3141601440429687,
#   112.8662109375,
#   0.054537390136718746,
#   123.6083984375,
#   0.07796199951171875,
#   111.8896484375,
#   0.2917115600585937,
#   109.2529296875,
#   0.28780745849609374,
#   90.8935546875,
#   0.3076939758300781,
#   91.44287109375,
#   0.3505394635391233,
#   74.76001739501953,
#   0.32148998294532294,
#   68.38041365146637,
#   0.09534695483565334,
#   69.86439228057861,
#   0.05757069377303125,
#   123.78580570220947,
#   0.0874673825608194,
#   125.75397789478302,
#   0.3413139649119228,
#   99.2480181902647,
#   0.2901537018641829,
#   94.34773772954941,
#   0.08735379658699044,
#   102.13322639465332,
#   0.29202430374898014,
# ...
