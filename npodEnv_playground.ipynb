# %%
from npodEnv import NpodEnv
env = NpodEnv()
env.ver()
# Out:
# 0.1

# %%
observation = env.run()
# Out:
# [1] "dopt"
# [1] "PSI"
# [1] "Multi prob"
# [1] "Sim time:"
#    user  system elapsed
#   2.788   0.060   2.865
# [1] "prob time:"
#    user  system elapsed
#  17.268   0.060  17.515
# $fobj
# [1] 118.6837
#
# $lambda
#     [1] 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11
#     [6] 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11
#    [11] 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11
#    [16] 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11 9.534438e-11
#    [21] 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11
#    [26] 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11
#    [31] 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11
#    [36] 2.716631e-10 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11
#    [41] 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11 9.472179e-11
#    [46] 9.472179e-11 9.472179e-11 1.265909e-10 9.472179e-11 9.472179e-11
# ...

# %%
observation.keys()
# Out:
# dict_keys(['count', 'theta', 'w', 'LogLikelihood', 'a', 'b', 'c0', 'c1'])
